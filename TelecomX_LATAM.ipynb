# %% [markdown]
# #📌 Extracción

# %% [markdown]
# * Fuente: Archivos JSON (JAVA SCRIPT OBJECT NOTATION) | Fromato uniforme destino: DataFrame

# %%
import pandas as pd

# %%
df_telecomx = pd.read_json('/content/TelecomX_Data.json')

# %%
df_telecomx.tail()
# Out:
#       customerID Churn                                           customer  \
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# * Cnociendo el conjunto de datos

# %%
df_telecomx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
df_telecomx.describe()
# Out:
#         customerID Churn                                           customer  \
# count         7267  7267                                               7267
# unique        7267     3                                                891
# top     9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# freq             1  5174                                                223
#
#                                                  phone  \
# count                                             7267
# unique                                               3
# top     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# freq                                              3495
#
#                                                  internet  \
# count                                                7267
# unique                                                129
# top     {'InternetService': 'No', 'OnlineSecurity': 'N...
# freq                                                 1581
#
# ...

# %%
df_telecomx.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %% [markdown]
# * Normalizando Archivos JSON

# %%
df_telecomx.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
# Columnas a normalizar
columns_to_normalize = ['customer', 'phone', 'internet', 'account']

# Crear una lista para almacenar los DataFrames normalizados
normalized_dfs = []

# Normalizar cada columna y añadir el resultado a la lista
for col in columns_to_normalize:
    df_telecomx = pd.json_normalize(df_telecomx[col])
    df_telecomx.tail()

# Concatenar los DataFrames normalizados
# Primero, incluimos las columnas originales 'customerID' y 'Churn'
df_telecomx_normalized = pd.concat([df_telecomx[['customerID', 'Churn']] ] + normalized_dfs, axis=1)

# Mostrar las primeras filas del DataFrame normalizado
display(df_telecomx_normalized.head())
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
display(df_telecomx_normalized.tail(20))
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 7247  9966-VYRTZ        Female              0     Yes        Yes      31
# 7248  9967-ATRFS    No  Female              0      No         No      19
# 7249  9968-FFVVH    No    Male              0      No         No      63
# 7250  9970-QBCDA    No  Female              0      No         No       6
# 7251  9971-ZWPBF    No    Male              1     Yes        Yes      34
# 7252  9972-EWRJS    No  Female              0     Yes        Yes      67
# 7253  9972-NKTFD    No  Female              0      No         No      28
# 7254  9972-VAFJJ    No  Female              1     Yes         No      53
# 7255  9974-JFBHQ    No    Male              0      No        Yes      64
# 7256  9975-GPKZU    No    Male              0     Yes        Yes      46
# 7257  9975-SKRNR    No    Male              0      No         No       1
# 7258  9978-HYCIN    No    Male              1     Yes        Yes      47
# ...

# %%
df_telecomx_normalized.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %% [markdown]
# * **Validar valores ausentes, duplicados, errores de formato e inconsistencias en las categorías**

# %%
# Valida valores unnicos por columna
pd.unique(df_telecomx_normalized['Churn'])
# Out:
# array(['No', 'Yes', ''], dtype=object)

# %%
# Valida valores unnicos por columna
pd.unique(df_telecomx_normalized['gender'])
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df_telecomx_normalized.describe()
# Out:
#        SeniorCitizen       tenure  Charges.Monthly
# count    7267.000000  7267.000000      7267.000000
# mean        0.162653    32.346498        64.720098
# std         0.369074    24.571773        30.129572
# min         0.000000     0.000000        18.250000
# 25%         0.000000     9.000000        35.425000
# 50%         0.000000    29.000000        70.300000
# 75%         0.000000    55.000000        89.875000
# max         1.000000    72.000000       118.750000

# %%
# Columnas a validar valores únicos
columns_values_unique = ['Churn', 'gender', 'SeniorCitizen', 'Partner',
       'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
       'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
       'PaperlessBilling', 'PaymentMethod']

for col in columns_values_unique:
    print(col + ': ' + str(pd.unique(df_telecomx_normalized[col])))
# Out:
# Churn: ['No' 'Yes' '']
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: ['Yes' 'No']
# Dependents: ['Yes' 'No']
# tenure: [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 11 37 49 66
#  67 20 43 59 12 27  2 25 29 14 35 64 39 40  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 51 31 36 17 18 38 42
#   0]
# PhoneService: ['Yes' 'No']
# MultipleLines: ['No' 'Yes' 'No phone service']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['Yes' 'No' 'No internet service']
# StreamingTV: ['Yes' 'No' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['One year' 'Month-to-month' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']

# %%
df_telecomx_normalized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
# Charges.Total  debe ser un cammpo float pero hay valores con cadenas vacias con valores ausentes por lo que no permite pasar a float directamente se debe remplazar antes esos faltantes
import numpy as np
df_telecomx_normalized['Charges.Total'] = df_telecomx_normalized['Charges.Total'].apply(lambda x : x.replace('$','').replace(',','.').replace(' reais','').strip())
#df_telecomx_normalized['Charges.Total '] =
#df_telecomx_normalized['Charges.Total'].astype(np.float64)

# %%
import numpy as np
# Reemplazar cadenas vacías con NaN
df_telecomx_normalized['Charges.Total'] = df_telecomx_normalized['Charges.Total'].replace('', np.nan)
# Convertir la columna a tipo numérico, manejando los NaN
df_telecomx_normalized['Charges.Total'] = df_telecomx_normalized['Charges.Total'].astype(np.float64)
display(df_telecomx_normalized.head())
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
df_telecomx_normalized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
# Filtrar el DataFrame para mostrar las filas donde 'Charges.Total' es NaN
nan_charges_total_rows = df_telecomx_normalized[df_telecomx_normalized['Charges.Total'].isnull()]

# Mostrar los registros encontrados
display(nan_charges_total_rows)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 975   1371-DWPAZ    No  Female              0     Yes        Yes       0
# 1775  2520-SGTTA    No  Female              0     Yes        Yes       0
# 1955  2775-SEFEE    No    Male              0      No        Yes       0
# 2075  2923-ARZLG    No    Male              0     Yes        Yes       0
# 2232  3115-CZMZD    No    Male              0      No        Yes       0
# 2308  3213-VVOLG    No    Male              0     Yes        Yes       0
# 2930  4075-WKNIU    No  Female              0     Yes        Yes       0
# 3134  4367-NUYAO    No    Male              0     Yes        Yes       0
# 3203  4472-LVYGI    No  Female              0     Yes        Yes       0
# 4169  5709-LVOEQ    No  Female              0     Yes        Yes       0
# 5599  7644-OMVMY    No    Male              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# ...

# %%
# 224 registros tienen el campo 'Churn' con un string vacio...
df_telecomx_normalized[df_telecomx_normalized['Churn']== '']
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    0047-ZHDTW        Female              0      No         No      11
# 75    0120-YZLQA          Male              0      No         No      71
# 96    0154-QYHJU          Male              0      No         No      29
# 98    0162-RZGMZ        Female              1      No         No       5
# 175   0274-VVQOQ          Male              1     Yes         No      65
# ...          ...   ...     ...            ...     ...        ...     ...
# 7158  9840-GSRFX        Female              0      No         No      14
# 7180  9872-RZQQB        Female              0     Yes         No      49
# 7211  9920-GNDMB          Male              0      No         No       9
# 7239  9955-RVWSC        Female              0     Yes        Yes      67
# 7247  9966-VYRTZ        Female              0     Yes        Yes      31
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# ...

# %%
# asigno nan porque es desconocido el porque el cliente dejo o no la empresa.
import numpy as np

# Reemplazar las cadenas vacías en la columna 'Churn' con NaN
df_telecomx_normalized['Churn'] = df_telecomx_normalized['Churn'].replace('', np.nan)

# Verificar si se realizaron los reemplazos mostrando la cuenta de valores NaN en 'Churn'
display(df_telecomx_normalized['Churn'].isnull().sum())

# mostrar los valores únicos de nuevo para confirmar que '' ya no está
display(pd.unique(df_telecomx_normalized['Churn']))
# Out:
# np.int64(224)

# %%
display(pd.unique(df_telecomx_normalized['Churn']))
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
